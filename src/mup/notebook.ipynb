# %%
from plotting import *

history_dict = get_wandb_history_logs("berkeargin","mup-transformer-coordcheck")
summary_df = get_wandb_summary_logs("berkeargin","mup-transformer-training")

# %%
# Coordinate check
plot_coord_summaries(history_dict, steps=range(0,10))

# %%
# Validation accuracy
plot_val_accuracy(summary_df)

# %%
# Losses
plot_losses(summary_df)
